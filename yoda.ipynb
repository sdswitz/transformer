# %%
import pandas as pd
import torch

# %%
pth = "data/test-movie.csv"
df = pd.read_csv(pth)
print(df.head())
# Out:
#                                                 text
# 0                                     CARTER   No.\n
# 1  SIDNEY   Cotton, there isn't one day, one hour...
# 2  COWAN   Further... what are you talking about,...
# 3  LOTHOS   The other two -- the new ones. Where ...
# 4                               ANN   Ted Sheldon.\n

# %%
len(df)
# Out:
# 91414
