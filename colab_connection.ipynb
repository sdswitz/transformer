# %%
import torch
import os

# %%
torch.cuda.is_available()
# Out:
# True

# %%
print(os.getcwd())
os.makedirs('repo', exist_ok=True)
# Out:
# /content

# %%
# !cd repo && git clone https://github.com/sdswitz/transformer.git
# Out:
# Cloning into 'transformer'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 57 (delta 23), reused 49 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 928.08 KiB | 8.44 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !cd repo/transformer/tokenizer && ls
# Out:
# basic_bpe.py  __init__.py  __pycache__	train.py

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/content/repo/transformer'

# %%
from tokenizer.basic_bpe import BasicTokenizer
